# %%
import pandas as pd

# %%
# read the csv into a pandas dataframe
df = pd.read_json("contradictions_datasets_fsis_guidelines.zip", orient='records', compression='infer')

# %%
# check out how many row and columns out dataframe has
df.shape
# Out:
# (133, 11)

# %%
# check out the column names in our dataframe
df.columns
# Out:
# Index(['file_name', 'title', 'num', 'id', 'corpus', 'source_page_url', 'url',
#        'type', 'n_pages', 'word_count', 'text_by_page'],
#       dtype='object')

# %%
# look at the first 5 rows of our dataframe
df.head()
# Out:
#            file_name                                              title  \
# 0  FSIS_GD_1995_0001  Labeling and Consumer Protection: Proprietary ...
# 1  FSIS_GD_1996_0001  Guidelines for Escherichia coli Testing for Pr...
# 2  FSIS_GD_1996_0002  Guidelines for Escherichia coli Testing for Pr...
# 3  FSIS_GD_2008_0003  Food Safety and Inspection Service (FSIS) Comp...
# 4  FSIS_GD_2008_0004  Guidance on Meaning of "Prohibited Substances"...
#
#                  num                                                 id  \
# 0  FSIS-GD-1995-0001  5e518f264996163d5bd4b99f66b5b973cd48d8f4437ba8...
# 1  FSIS-GD-1996-0001  2abf39a3c5374105e5b9b7c1de624c2949a5ea09895773...
# 2  FSIS-GD-1996-0002  5461301f47df3624107b0587ed6273895b6d26e29b4d2c...
# 3  FSIS-GD-2008-0003  8fb0ccb1e3be736fcbb6171a1d4b195a326e15e0cccd38...
# 4  FSIS-GD-2008-0004  fd8a79ba35be9424b128aa42dc60323163c5e31fbbadce...
#
#             corpus                                   source_page_url  \
# 0  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 1  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 2  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 3  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 4  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
#
#                                                  url type  n_pages  \
# 0  https://www.fsis.usda.gov/sites/default/files/...  pdf       15
# 1  https://www.fsis.usda.gov/sites/default/files/...  pdf       22
# 2  https://www.fsis.usda.gov/sites/default/files/...  pdf       20
# 3  https://www.fsis.usda.gov/sites/default/files/...  pdf        2
# 4  https://www.fsis.usda.gov/sites/default/files/...  pdf        2
#
#    word_count                                       text_by_page
# 0        5896  [Propietary Mixture Suppliers and Manufacturer...
# 1        7444  [Guidelines for Escherichia coli Testing for P...
# 2        6043  [---------------------------------------------...
# 3         484  [Letter to Industry - July 13, 1998 Dear Sir o...
# 4         744  [Food Safety and Inspection Service United Sta...

# %%
df.tail()
# Out:
#              file_name                                              title  \
# 128  FSIS_GD_2022_0004        HACCP Model for Raw Non-Intact Egg Products
# 129  FSIS_GD_2022_0005                         Label Application Guidance
# 130  FSIS_GD_2022_0006  HACCP Model for Raw Intact Farm-raised Catfish...
# 131  FSIS_GD_2022_0007  HACCP Model for Raw Intact Wild-caught Catfish...
# 132  FSIS_GD_2023_0001                  FSIS Guideline for Label Approval
#
#                    num                                                 id  \
# 128  FSIS-GD-2022-0004  a9bf2768d222d60124de42692261a8f988f6690a2816e9...
# 129  FSIS-GD-2022-0005  2c2c8504481a85ba10281358ff5b09d50f33d131d959d3...
# 130  FSIS-GD-2022-0006  3eded229ecc6784ed452996e19c4e1720aa2f4aa5cd42d...
# 131  FSIS-GD-2022-0007  153afca7a3aee4bb17b8d1ecd2436b05386c98becf0a8e...
# 132  FSIS-GD-2023-0001  f3fc42eeecf0880230b784fa2c7670cbb85a085f9afad8...
#
#               corpus                                   source_page_url  \
# 128  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 129  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 130  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 131  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
# 132  fsis_guidelines  https://www.fsis.usda.gov/policy/fsis-guidelines
#
#                                                    url type  n_pages  \
# 128  https://www.fsis.usda.gov/sites/default/files/...  pdf       14
# 129  https://www.fsis.usda.gov/sites/default/files/...  pdf        1
# 130  https://www.fsis.usda.gov/sites/default/files/...  pdf       14
# 131  https://www.fsis.usda.gov/sites/default/files/...  pdf       13
# 132  https://www.fsis.usda.gov/sites/default/files/...  pdf       37
#
#      word_count                                       text_by_page
# 128        3537  [HACCP Model for Unpasteurized Liquid Egg (Raw...
# 129         261  [Label Application Guidance The Labeling and P...
# 130        4230  [A Generic HACCP Model for a Raw Intact Farm-r...
# 131        4109  [A Generic HACCP Model for a Raw Intact Wild-c...
# 132       13012  [FSIS Guideline for Label Approval January 202...

# %%
# see what an example of the text looks like
print(df['text_by_page'].iloc[-1])
# Out:
# ['FSIS Guideline for Label Approval January 2023 FSIS-GD-2023-0001 This guideline is designed to help establishments determine whether their labels must be submitted to FSIS Labeling and Program Delivery Staff (LPDS) for approval. 1', 'Table of Contents Preface..................................................................................................................................... 3 Congressional Review Act ........................................................................................................... 3 Purpose.................................................................................................................................... 3 Reason for Reissuing the Guideline............................................................................................... 4 Changes from the Previous Version of the Guideline ....................................................................... 4 How to Effectively Use the Guideline ............................................................................................ 5 How to Comment on the Guideline .............................................................................................. 5 Questions Regarding Topics in this Guideline ................................................................................. 6 Background............................................................................................................................... 7 Special Statements and Claims (9 CFR 412.1 (c) (3)) ........................................................................ 8 Factual Statements and Claims Generically Approved (9 CFR 412.2) .................................................. 8 Changes to Labels with Approved Special Statements and Claims That Do Not Require Additional LPDS Review..................................................................................................................................... 9 Changes to Labels with Approved Special Statements and Claims that Require Additional LPDS Review . 9 Blanket Label Approvals (Labels for product line or multiple products with identical claims)................10 Special Statements and Claims Generically Approved After the First Approval from LPDS....................11 Negative Claims........................................................................................................................11 Export Labels that Deviate from Domestic Requirements and Geographic Landmark Claims on Labels ..12 Additional Information for Label Approval ....................................................................................13 Appendix 1: Special Statements and Claims ..................................................................................14 Appendix 2: Factual Statements and Claims..................................................................................17 Appendix 3: Changes to labels approved with special statements and claims not requiring additional LPDS review.............................................................................................................................21 Appendix 4: Changes to labels with special statements and claims that require LPDS review................23 Appendix 5: Blanket Label Approvals (Product Line or Multiple Products with Identical Claims)............24 Appendix 6: Special Statements and Claims Generically Approved After the First Approval from LPDS...24 Appendix 7: Negative Claims ......................................................................................................25 Appendix 8: Export Labels with deviations from domestic requirements and Geographic Claims on Labels ..............................................................................................................................................32 Appendix 9: Additional Information for Label Approval ..................................................................35 2', 'Preface This is a revised version of the FSIS Gui ...

# %%
fsis.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8l/2b2rpl1d28n6ygfclrc_kmhr0000gn/T/ipykernel_87481/1403762717.py in <module>
# ----> 1 fsis.head()
#
# NameError: name 'fsis' is not defined

# %%
# Using DataFrame.copy() create new DaraFrame.
df2 = df[['Courses', 'Fee']].copy()
